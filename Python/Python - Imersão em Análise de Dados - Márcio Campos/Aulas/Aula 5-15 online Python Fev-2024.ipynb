# %%
# ----------------------------------------------------------------------------------------------------------------------- #
# Márcio Campos
# ----------------------------------------------------------------------------------------------------------------------- #
# Curso de Python
# @sou.devops
# 26/Fev/2024
# ----------------------------------------------------------------------------------------------------------------------- #
# Assuntos abordados :
# - Estruturas de dados
# - Funções Nativas
# - Operadores
# - f-string
# - apagando variável e ajudando o coletor de lixo
# - definindo variável global // local
# - utilizando padrão snake_case e CamelCase (funções de usuário e classes)
# - importando bibliotecas
# - mnemônicos
# - um assunto chamado data
# ----------------------------------------------------------------------------------------------------------------------- #
# Dicionário de menmônicos 
#       salar = salário

# %% [raw]
# Nomes de variáveis e funções.
# Há várias convenções de nomes aceitas pela PEP 8, mas a mais comum é a snake_case, onde as palavras são separadas por sublinha(_) e a completamente em caixa baixa. É comum ainda que se comece o nome de uma variável com sublinha, indicando que esta variável é de uso interno(como se fosse privada, mas Python não possui encapsulamento, mantenha em mente que isto é apenas uma convenção, ainda é possível acessar estas variáveis).
#
# Nomes de Modulos e Pacotes.
# A PEP encoraja que sejam utilizados nomes curtos, em caixa baixa. Sublinha pode ser utilizado para promover a legibilidade, exceto em nomes de pacotes.
#
# Nomes de Classes.
# Nomes de classe normalmente seguem o padrão CamelCase, com a primeira letra de cada palavra em caixa alta.

# %%
# Variáveis c/ Tipo (int) - Inteiro

# %%
ano_nascto  = "1968"       # mnemônico (dicionário) nascto = nascimento  
divida      = -100
idade       = 55
salario     = 1000
nota        = 9
notas       = [10, 8.6, 7, 3, 4.5, 9.3] # Estrutura de dados List, somente com inteiros e float

print("Divida      :", divida, abs(divida), type(divida))            # valor absoluta, sem alterar o tipo da variável
print("Idade       :", idade, idade * 2, type(idade))                # operação sem alterar o tipo da variável
print("Salario     :", salario, float(salario),type(salario))        # conversão de tipo, sem alterar o tipo da variável
print("Nota        :", nota, pow(nota,2),type(nota))                 # exponenciação sem alterar o tipo da variável
print("Nascto      :", ano_nascto, int(ano_nascto),type(ano_nascto)) # conversão de tipo, sem alterar o tipo da variável
print("Resto       :", salario, divmod(salario, 50))                 # quociente e resto, sem alterar o tipo da variável
print("Arredondar  :", salario, salario/3.2, round(salario/3.2))     # arredondamento, sem alterar o tipo da variável
print("Máximo      :", notas, type(notas), max(notas))               # máximo, sem alterar o tipo de dado da estrutura
print("Máximo      :", notas, type(notas), min(notas))               # minimo, sem alterar o tipo de dado da estrutura
print("Elemento    :", notas, int(round(notas[1])))                  # abs pontual, sem alterar o tipo de dado da estrutura
print("Somar       :", notas, type(sum(notas)), type(notas))         # somatorio, sem alterar o tipo de dado da estrutura
# Out:
# Divida      : -100 100 <class 'int'>
# Idade       : 55 110 <class 'int'>
# Salario     : 1000 1000.0 <class 'int'>
# Nota        : 9 81 <class 'int'>
# Nascto      : 1968 1968 <class 'str'>
# Resto       : 1000 (20, 0)
# Arredondar  : 1000 312.5 312
# Máximo      : [10, 8.6, 7, 3, 4.5, 9.3] <class 'list'> 10
# Máximo      : [10, 8.6, 7, 3, 4.5, 9.3] <class 'list'> 3
# Elemento    : [10, 8.6, 7, 3, 4.5, 9.3] 9
# Somar       : [10, 8.6, 7, 3, 4.5, 9.3] <class 'float'> <class 'list'>

# %%
print("------------------------------------------------")
print("Antes  ",ano_nascto, type(ano_nascto))
ano_nascto = int(ano_nascto)
print("Depois ",ano_nascto, type(ano_nascto))
print("------------------------------------------------")

# mnemonicos documentação
# sal = salário
# fer = férias
# ter = 1/3, um terço, terça-feria, terceiro

# sal_fer é a terça parte do salário
# ----------------------------------

sal_fer = ""

print("Qual o tipo de sal_fer", type(sal_fer))

sal_fer = salario * 10 / 30 # Operador de atribuição

print("1/3 Férias :", sal_fer, type(sal_fer)) # sem formatação

print(f"1/3 Férias : US$ {sal_fer:,.2f}") # com formatação f-string

del sal_fer # apagando variável

global sal_fer

sal_fer = 1300.00
# Out:
# ------------------------------------------------
# Antes   1968 <class 'int'>
# Depois  1968 <class 'int'>
# ------------------------------------------------
# Qual o tipo de sal_fer <class 'str'>
# 1/3 Férias : 333.3333333333333 <class 'float'>
# 1/3 Férias : US$ 333.33

# %%
# Um assunto chamado data
# -----------------------

# importa a classe datetime que é usada para representar datas e horas em Python
# ----------------------------------------------------------------------------------------------------------------------- #
from datetime import datetime

# importa a classe timedelta que é usada para representar diferenças entre datas e horas.
# ----------------------------------------------------------------------------------------------------------------------- #
from datetime import timedelta

# importa relativedelta, é uma classe que oferece funcionalidades avançadas para manipulação de datas e tempos em Python.
# Ela é especialmente útil para adicionar ou subtrair meses, anos, semanas, etc., de objetos datetime, 
# levando em consideração as diferenças nos comprimentos dos meses e anos.
# ----------------------------------------------------------------------------------------------------------------------- #
from dateutil.relativedelta import relativedelta

# strptime ("String Parse Time"):

# Este método é usado para converter strings em objetos datetime.
# Ele aceita dois argumentos: a string contendo a data e a hora a serem convertidas e um formato que especifica como
# a string está estruturada.
# O método strptime analisa a string de entrada de acordo com o formato especificado e retorna um objeto datetime
# correspondente.

aniversario       = "01/01/1968"

print("Aniversário       :", aniversario, datetime.strptime(aniversario, "%d/%m/%Y"), type(aniversario))

aniversario_primo = datetime.strptime(aniversario, "%d/%m/%Y")

print("Aniversário Primo :", aniversario_primo, type(aniversario_primo))
# Out:
# Aniversário       : 01/01/1968 1968-01-01 00:00:00 <class 'str'>
# Aniversário Primo : 1968-01-01 00:00:00 <class 'datetime.datetime'>

# %%
# strftime ("String Format Time"):

# Este método é usado para converter objetos datetime em strings formatadas, permitindo que você especifique o formato
# exato da string de saída.
# Ele aceita um argumento de formato, que é uma string que define como você deseja que a data e a hora sejam formatadas
# na string resultante.
# O método strftime retorna uma string formatada de acordo com o formato especificado.

print("Aniversário Primo :", aniversario_primo, datetime.strftime(aniversario_primo,"%d/%m/%Y %H:%M:%S"), type(aniversario_primo))

aniversario_tia = datetime.strftime(aniversario_primo,"%d/%m/%Y %H:%M:%S")

print("Aniversário Tia :", aniversario_tia+" (Dita)", type(aniversario_tia))
# Out:
# Aniversário Primo : 1968-01-01 00:00:00 01/01/1968 00:00:00 <class 'datetime.datetime'>
# Aniversário Tia : 01/01/1968 00:00:00 (Dita) <class 'str'>

# %%
# Vamos acrescentar dias, meses e anos a data ?
# ---------------------------------------------

# Para acrescentar dias, meses ou anos a um objeto datetime em Python, você pode usar a classe timedelta
# do módulo datetime.

# Acrescentando dia, meses e anos a uma variável Data
# ---------------------------------------------------

print("Criando a variável datatime")

data_referencia = datetime(2024, 2, 18) 

print("Referencia : ", data_referencia, type(data_referencia))

# timedelta(days=7) acrescenta 7 dias à data de referência.
# timedelta(weeks=4) acrescenta aproximadamente 1 mês (considerando 4 semanas).
# timedelta(days=365) acrescenta aproximadamente 1 ano (considerando 365 dias).

print("    7 dias : ", data_referencia + timedelta(days=7), type(data_referencia))
print(" 4 semanas : ", data_referencia + timedelta(weeks=4), type(data_referencia))
print("     1 ano : ", data_referencia + timedelta(days=365), type(data_referencia))

# Para adicionar um mês a um objeto datetime em Python, precisa considerar algumas situações especiais devido
# às diferenças no número de dias em cada mês. A maneira mais comum de lidar com isso é usar a biblioteca
# dateutil.relativedelta, que oferece uma maneira simples e eficaz de manipular datas e tempos em Python.
# ----------------------------------------------------------------------------------------------------------------------- #

data_futura = data_referencia + relativedelta(months=1)

print("     1 mês : ", data_futura, type(data_referencia))
# Out:
# Criando a variável datatime
# Referencia :  2024-02-18 00:00:00 <class 'datetime.datetime'>
#     7 dias :  2024-02-25 00:00:00 <class 'datetime.datetime'>
#  4 semanas :  2024-03-17 00:00:00 <class 'datetime.datetime'>
#      1 ano :  2025-02-17 00:00:00 <class 'datetime.datetime'>
#      1 mês :  2024-03-18 00:00:00 <class 'datetime.datetime'>

# %%
# ----------------------------------------------------------------------------------------------------------------------- # 
# Variáveis Locais:
# Variáveis definidas dentro de uma função têm escopo local.
# Elas só podem ser acessadas dentro da função onde foram definidas.
# As variáveis locais são criadas quando a função é chamada e são destruídas quando a função retorna.
# Tentar acessar uma variável local fora do escopo da função onde foi definida resultará em um erro.
# ---------------------------------------------------------------------------------------------------------------------- #

# ---------------------------------------------------------------------------------------------------------------------- # 
# Variáveis Globais:
# Variáveis definidas fora de qualquer função têm escopo global.
# Elas podem ser acessadas de qualquer lugar do código, incluindo dentro de funções.
# Se uma variável global é modificada dentro de uma função, ela precisa ser declarada como global dentro da função.
# Variáveis globais são criadas quando são atribuídas um valor pela primeira vez e existem até o programa terminar
# ou até serem excluídas explicitamente.
# ---------------------------------------------------------------------------------------------------------------------- #

"""
    Funções do Python para descobrir se a variável é global ou local
        globals() / locals()
    
    Melhores práticas : desenvolver com documentação, lógica e algoritimo estruturado
"""

# (escopo global)
# ---------------

print("Global")

x = 10

def AulaVariavel():
    global x
    x += 10
    print(x)

AulaVariavel()

print(x)

# (escopo local)
# ---------------
print("Local")
y = 10

def AulaVariavel():    
    y = 5 
    print(y)

AulaVariavel()

print(y)
# Out:
# Global
# 20
# 20
# Local
# 5
# 10

# %%
# Variáveis c/ Tipo (str) - String

# %%
nascto     = "06/05/1968"
cidade     = " São Paulo "
estado     = "SP"

# %%
nome       = "marcio campos"
print(len(nome))
# Out:
# 13

# %%
instagram  = "@Sou.Devops"
print(instagram.lower())
print(instagram.upper())
print(instagram.upper().lower())
# Out:
# @sou.devops
# @SOU.DEVOPS
# @sou.devops

# %%
pais       = "Brasil tem muitos Estados é maravilhoso !"
print(pais.replace("maravilhoso", "peq"))
print(pais.replace("tem", "há"))
# Out:
# Brasil tem muitos Estados é peq !
# Brasil há muitos Estados é maravilhoso !

# %%
nome = "marcio campos de oliveira"
print(nome.capitalize())
# Out:
# Marcio campos de oliveira

# %%
# strip(), lstrip(), rstrip()
# Estas funções removem espaços em branco do início (left), final (right) ou de ambos os lados (ambos) de uma string:

cidade = " São Paulo "
print(cidade)
print(cidade.strip() + "SP")
print(cidade.lstrip() + "SP")
print(cidade.rstrip() + "SP" )
# Out:
#  São Paulo
# São PauloSP
# São Paulo SP
#  São PauloSP

# %%
# ----------------------------------------------------------------------------------------------------------------------- #
# Os métodos rsplit() e split() são usados para dividir uma string em substrings com base em um separador e 
# retornar uma lista das substrings resultantes. A principal diferença entre eles está na direção em que a string é 
# dividida.

# O método split() divide uma string em substrings usando um separador especificado
# e retorna uma lista das substrings resultantes.

# O método rsplit() é semelhante ao split(), mas divide a string da direita para a esquerda.
# ----------------------------------------------------------------------------------------------------------------------- #

frase = "Hoje é dia de aprender fundamentos e conceitos de Python"
print(frase.split())
print(frase.rsplit())

texto = frase.split(maxsplit=2)
print(texto)

linguagens = "C/C++ - Cobol - PHP - Python - Javascript - Node.JS - Rust Julia"
texto      = linguagens.split("-") 
print(texto)

print(frase)
# Out:
# ['Hoje', 'é', 'dia', 'de', 'aprender', 'fundamentos', 'e', 'conceitos', 'de', 'Python']
# ['Hoje', 'é', 'dia', 'de', 'aprender', 'fundamentos', 'e', 'conceitos', 'de', 'Python']
# ['Hoje', 'é', 'dia de aprender fundamentos e conceitos de Python']
# ['C/C++ ', ' Cobol ', ' PHP ', ' Python ', ' Javascript ', ' Node.JS ', ' Rust Julia']
# Hoje é dia de aprender fundamentos e conceitos de Python

# %% [raw]
# # ----------------------------------------------------------------------------------------------------------------------- #
# # A Estrutura de Dados list
# # ----------------------------------------------------------------------------------------------------------------------- #
#
# Uma lista é uma estrutura de dados que armazena uma coleção ordenada de elementos. Esses elementos podem ser de diferentes tipos de dados, como números, strings, booleanos, e até mesmo outras listas. As listas são mutáveis, o que significa que você pode modificar, adicionar ou remover elementos conforme necessário. A sintaxe básica para criar uma lista em Python é colocar os elementos entre colchetes [], separados por vírgulas. (Podemos considerar um Vetor ou Matriz?)
#
# As listas em Python são uma das estruturas de dados mais flexíveis e amplamente utilizadas devido à sua versatilidade e capacidade de manipulação de dados. Elas são amplamente empregadas em várias aplicações, desde tarefas simples até projetos complexos de análise, ciência de dados e desenvolvimento de software.

# %%
minha_lista = [1, 2, 3, 4, 5, "Maria", True, 23.56]
print(minha_lista)
print(type(minha_lista))
print(type(minha_lista[7]))
# Out:
# [1, 2, 3, 4, 5, 'Maria', True, 23.56]
# <class 'list'>
# <class 'float'>

# %%
minha_lista = [1, 2, "06/05/1968", 4, 5]
print(minha_lista)
print(type(minha_lista))
print(type(minha_lista[0]))
# Out:
# [1, 2, '06/05/1968', 4, 5]
# <class 'list'>
# <class 'int'>

# %%
from datetime import datetime
from datetime import timedelta
from dateutil.relativedelta import relativedelta

minha_lista = [1, 2, "06/05/1968", 4, 5]

print(minha_lista)
print(type(minha_lista))
print(type(minha_lista[2]))
print("-------------------------------")
print(type(datetime.strptime(minha_lista[2], '%d/%m/%Y')))
print(datetime.strptime(minha_lista[2], '%d/%m/%Y'))
print("-------------------------------")
print(type(minha_lista[2]))

# Sabe o que significa linha de código e sentença?
# Quando a "setença" não tem atribuição =, não há covnersão ou tipagem....
# Out:
# [1, 2, '06/05/1968', 4, 5]
# <class 'list'>
# <class 'str'>
# -------------------------------
# <class 'datetime.datetime'>
# 1968-05-06 00:00:00
# -------------------------------
# <class 'str'>

# %%
minha_lista = [1, 2, "06/05/1968", 4, 5, ["Maça","Melancia","Caju",[3.1,18.9]], datetime.strptime(minha_lista[2], '%d/%m/%Y')]
print(minha_lista)
print(minha_lista[5][3][1])
# Out:
# [1, 2, '06/05/1968', 4, 5, ['Maça', 'Melancia', 'Caju', [3.1, 18.9]], datetime.datetime(1968, 5, 6, 0, 0)]
# 18.9

# %% [raw]
# Ponto de atenção :
#
# - Em Python, o tamanho máximo de uma lista é limitado apenas pela quantidade de memória disponível no sistema. Isso significa que o tamanho máximo teórico de uma lista é limitado pela quantidade de RAM disponível no seu computador ou servidor.
#
# - No entanto, na prática, o tamanho máximo de uma lista pode ser afetado por vários fatores, incluindo a arquitetura do sistema, a versão do Python e a quantidade de memória disponível para o processo Python em execução.
#
# - Em sistemas de 64 bits, o tamanho máximo de uma lista pode ser muito grande, muitas vezes muito além do que seria prático ou útil em situações do mundo real. Por exemplo, você pode criar listas com milhões ou até bilhões de elementos, desde que haja memória suficiente disponível no sistema.
#
# - Por outro lado, em sistemas de 32 bits, o tamanho máximo de uma lista é limitado pela quantidade máxima de memória endereçável pelo sistema, o que geralmente é menor do que em sistemas de 64 bits. Isso pode limitar o tamanho máximo prático de uma lista em comparação com sistemas de 64 bits.

# %%
# Criando uma lista com 10 linhas e 6 colunas
tabela_dados = [
    ["João", "1990-05-15", 3000.50, 31, "SP", False],
    ["Maria", "1985-08-20", 4000.75, 36, "RJ", False],
    ["Pedro", "1978-03-10", 5000.25, 43, "MG", True],
    ["Ana", "1992-11-28", 2500.80, 29, "RS", False],
    ["Carlos", "1980-07-03", 3500.60, 41, "BA", False],
    ["Lúcia", "1975-12-18", 6000.90, 46, "PR", True],
    ["Mariana", "1987-09-25", 3200.45, 34, "SC", False],
    ["Fernando", "1995-02-09", 2800.30, 27, "PE", False],
    ["Lucas", "1970-06-14", 7000.70, 52, "AM", False],
    ["Amanda", "1983-04-30", 4200.55, 39, "CE", True]
]

# Imprimindo a tabela de dados linha por linha com valores de salário formatados
for linha in tabela_dados:
    # Formatando o valor do salário para duas casas decimais
    linha[2] = "{:.2f}".format(linha[2])
    print(linha)
# Out:
# ['João', '1990-05-15', '3000.50', 31, 'SP', False]
# ['Maria', '1985-08-20', '4000.75', 36, 'RJ', False]
# ['Pedro', '1978-03-10', '5000.25', 43, 'MG', True]
# ['Ana', '1992-11-28', '2500.80', 29, 'RS', False]
# ['Carlos', '1980-07-03', '3500.60', 41, 'BA', False]
# ['Lúcia', '1975-12-18', '6000.90', 46, 'PR', True]
# ['Mariana', '1987-09-25', '3200.45', 34, 'SC', False]
# ['Fernando', '1995-02-09', '2800.30', 27, 'PE', False]
# ['Lucas', '1970-06-14', '7000.70', 52, 'AM', False]
# ['Amanda', '1983-04-30', '4200.55', 39, 'CE', True]

# %%
# ----------------------------------------------------------------------------------------------------------------------- #
# Imaginando que nosso list tem milhões de linhas, como realizar uma busca ?
# ----------------------------------------------------------------------------------------------------------------------- #
# enumerate() é uma função embutida em Python que permite iterar sobre uma sequência (string, list, tupla) enquanto
# acompanha automaticamente o número de iterações (o índice) a partir de um valor inicial.
# ----------------------------------------------------------------------------------------------------------------------- #

# ----------------------------------------------------------------------------------------------------------------------- #
# Obter a data e hora atual
# ----------------------------------------------------------------------------------------------------------------------- #
data_hora_atual_inicio = datetime.now()
data_hora_formatada    = data_hora_atual_inicio.strftime("%d/%m/%Y %H:%M:%S.%f")
print(f"Inicio análise    : {data_hora_formatada}")

# Criando uma lista com 10 linhas e 6 colunas
tabela_dados = [
    ["João", "1990-05-15", 3000.50, 31, "SP", False],
    ["Maria", "1985-08-20", 4000.75, 36, "RJ", False],
    ["Pedro", "1978-03-10", 5000.25, 43, "MG", True],
    ["Ana", "1992-11-28", 2500.80, 29, "RS", False],
    ["Carlos", "1980-07-03", 3500.60, 41, "BA", False],
    ["Lúcia", "1975-12-18", 6000.90, 46, "PR", True],
    ["Mariana", "1987-09-25", 3200.45, 34, "SC", False],
    ["Fernando", "1995-02-09", 2800.30, 27, "PE", False],
    ["Lucas", "1970-06-14", 7000.70, 52, "AM", False],
    ["Amanda", "1983-04-30", 4200.55, 39, "CE", True]
]

# Valor a ser procurado
valor_procurado = 2500.80

print(tabela_dados)

# Procurando o valor na lista
for linha_index, linha in enumerate(tabela_dados):
    print("Índice :", linha_index)
    print("linha : ", linha)
    for coluna_index, valor in enumerate(linha):
        print("Coluna : ", coluna_index)
        print("Conteúdo : ", valor)
        if valor == valor_procurado:
            print(f"Valor encontrado na linha {linha_index} e coluna {coluna_index}")
            
# ----------------------------------------------------------------------------------------------------------------------- #
# Obter a data e hora atual
# ----------------------------------------------------------------------------------------------------------------------- #
data_hora_atual_final   = datetime.now()
data_hora_formatada     = data_hora_atual_final.strftime("%d/%m/%Y %H:%M:%S.%f")
print(f"Fim da análise    : {data_hora_formatada}")
print("------------------------------------------")

diferenca_tempo         = data_hora_atual_final - data_hora_atual_inicio

# Converter a diferença para milissegundos
diferenca_tempo_em_milissegundos = diferenca_tempo.total_seconds() * 1000

print(f"Diferença de tempo em milissegundos: {diferenca_tempo_em_milissegundos}")

# ----------------------------------------------------------------------------------------------------------------------- #
# Vamos pensar ?
# E quando nosso list estiver com milhões ou bilhões de linhas (se é que iremos deixar isso acontecer!),
# mas em um conjunto grande de informações, isso demoraria ? Depende da lógica, algoritimo, condições e etc. !
# ----------------------------------------------------------------------------------------------------------------------- #
# Out:
# Inicio análise    : 27/02/2024 20:25:13.454309
# [['João', '1990-05-15', 3000.5, 31, 'SP', False], ['Maria', '1985-08-20', 4000.75, 36, 'RJ', False], ['Pedro', '1978-03-10', 5000.25, 43, 'MG', True], ['Ana', '1992-11-28', 2500.8, 29, 'RS', False], ['Carlos', '1980-07-03', 3500.6, 41, 'BA', False], ['Lúcia', '1975-12-18', 6000.9, 46, 'PR', True], ['Mariana', '1987-09-25', 3200.45, 34, 'SC', False], ['Fernando', '1995-02-09', 2800.3, 27, 'PE', False], ['Lucas', '1970-06-14', 7000.7, 52, 'AM', False], ['Amanda', '1983-04-30', 4200.55, 39, 'CE', True]]
# Índice : 0
# linha :  ['João', '1990-05-15', 3000.5, 31, 'SP', False]
# Coluna :  0
# Conteúdo :  João
# Coluna :  1
# Conteúdo :  1990-05-15
# Coluna :  2
# Conteúdo :  3000.5
# Coluna :  3
# Conteúdo :  31
# Coluna :  4
# Conteúdo :  SP
# Coluna :  5
# Conteúdo :  False
# Índice : 1
# linha :  ['Maria', '1985-08-20', 4000.75, 36, 'RJ', False]
# Coluna :  0
# Conteúdo :  Maria
# Coluna :  1
# Conteúdo :  1985-08-20
# Coluna :  2
# ...

# %%
# ----------------------------------------------------------------------------------------------------------------------- #
# Consigo ser mais rápido na pesquisa ?
# ----------------------------------------------------------------------------------------------------------------------- #

# ----------------------------------------------------------------------------------------------------------------------- #
# Obter a data e hora atual
# ----------------------------------------------------------------------------------------------------------------------- #
data_hora_atual_inicio = datetime.now()
data_hora_formatada    = data_hora_atual_inicio.strftime("%d/%m/%Y %H:%M:%S.%f")
print(f"Inicio análise    : {data_hora_formatada}")

tabela_dados = [
    ["João", "1990-05-15", 3000.50, 31, "SP", False],
    ["Maria", "1985-08-20", 4000.75, 36, "RJ", False],
    ["Pedro", "1978-03-10", 5000.25, 43, "MG", True],
    ["Ana", "1992-11-28", 2500.80, 29, "RS", False],
    ["Carlos", "1980-07-03", 3500.60, 41, "BA", False],
    ["Lúcia", "1975-12-18", 6000.90, 46, "PR", True],
    ["Mariana", "1987-09-25", 3200.45, 34, "SC", False],
    ["Fernando", "1995-02-09", 2800.30, 27, "PE", False],
    ["Lucas", "1970-06-14", 7000.70, 52, "AM", False],
    ["Amanda", "1983-04-30", 4200.55, 39, "CE", True]
]

valor_procurado = 6000.90

# ----------------------------------------------------------------------------------------------------------------------- #
# A função any() é uma função embutida do Python que retorna True se pelo menos um dos elementos em um iterável
# for verdadeiro. Se o iterável estiver vazio, any() retorna False.
# ----------------------------------------------------------------------------------------------------------------------- #

# Verificar se o valor procurado está presente em qualquer uma das sublistas
encontrado = any(valor_procurado in linha for linha in tabela_dados)

if encontrado:
    print(f"O valor {valor_procurado} está presente na lista.")
else:
    print(f"O valor {valor_procurado} não está presente na lista.")

# ----------------------------------------------------------------------------------------------------------------------- #
# Obter a data e hora atual
# ----------------------------------------------------------------------------------------------------------------------- #
data_hora_atual_final   = datetime.now()
data_hora_formatada     = data_hora_atual_final.strftime("%d/%m/%Y %H:%M:%S.%f")
print(f"Fim da análise    : {data_hora_formatada}")
print("------------------------------------------")
diferenca_tempo         = data_hora_atual_final - data_hora_atual_inicio

# Converter a diferença para milissegundos
diferenca_tempo_em_milissegundos = diferenca_tempo.total_seconds() * 1000

print(f"Diferença de tempo em milissegundos: {diferenca_tempo_em_milissegundos}")
# Out:
# Inicio análise    : 27/02/2024 20:25:03.912073
# O valor 6000.9 está presente na lista.
# Fim da análise    : 27/02/2024 20:25:03.913093
# ------------------------------------------
# Diferença de tempo em milissegundos: 1.02

# %%
# ----------------------------------------------------------------------------------------------------------------------- #
# Vamos transformar a lista em um Dataframe ?
# ----------------------------------------------------------------------------------------------------------------------- #
# Obter a data e hora atual
# ----------------------------------------------------------------------------------------------------------------------- #
data_hora_atual_inicio = datetime.now()
data_hora_formatada    = data_hora_atual_inicio.strftime("%d/%m/%Y %H:%M:%S.%f")
print(f"Inicio análise    : {data_hora_formatada}")

import pandas as pd

tabela_dados = [
    ["João", "1990-05-15", 3000.50, 31, "SP", False],
    ["Maria", "1985-08-20", 4000.75, 36, "RJ", False],
    ["Pedro", "1978-03-10", 5000.25, 43, "MG", True],
    ["Ana", "1992-11-28", 2500.80, 29, "RS", False],
    ["Carlos", "1980-07-03", 3500.60, 41, "BA", False],
    ["Lúcia", "1975-12-18", 6000.90, 46, "PR", True],
    ["Mariana", "1987-09-25", 3200.45, 34, "SC", False],
    ["Fernando", "1995-02-09", 2800.30, 27, "PE", False],
    ["Lucas", "1970-06-14", 7000.70, 52, "AM", False],
    ["Amanda", "1983-04-30", 4200.55, 39, "CE", True]
]

# Descrição das colunas
colunas = ["Nome", "Data de Nascimento", "Salário", "Idade", "Estado", "Ativo"]

# Converter a lista de listas para DataFrame do pandas
df = pd.DataFrame(tabela_dados, columns=colunas)

# Verificar se o valor procurado está presente no DataFrame
filtro = (df == valor_procurado)

if filtro.any().any():
    linha_index, coluna_index = filtro.stack().idxmax()
    print(f"O valor {valor_procurado} foi encontrado na linha {linha_index} e coluna {coluna_index}.")
else:
    print(f"O valor {valor_procurado} não foi encontrado no DataFrame.")
    
# ----------------------------------------------------------------------------------------------------------------------- #
# Obter a data e hora atual
# ----------------------------------------------------------------------------------------------------------------------- #
data_hora_atual_final   = datetime.now()
data_hora_formatada     = data_hora_atual_final.strftime("%d/%m/%Y %H:%M:%S.%f")
print(f"Fim da análise    : {data_hora_formatada}")
print("------------------------------------------")
diferenca_tempo         = data_hora_atual_final - data_hora_atual_inicio

# Converter a diferença para milissegundos
diferenca_tempo_em_milissegundos = diferenca_tempo.total_seconds() * 1000

print(f"Diferença de tempo em milissegundos: {diferenca_tempo_em_milissegundos}")
print("------------------------------------------")

# Salvar o DataFrame como arquivo CSV
df.to_csv("cadastro.csv", index=False)

print(df)
df.head(10)
# Out:
# Inicio análise    : 27/02/2024 20:44:31.085550
# O valor 2500.8 foi encontrado na linha 3 e coluna Salário.
# Fim da análise    : 27/02/2024 20:44:31.096935
# ------------------------------------------
# Diferença de tempo em milissegundos: 11.385
# ------------------------------------------
#        Nome Data de Nascimento  Salário  Idade Estado  Ativo
# 0      João         1990-05-15  3000.50     31     SP  False
# 1     Maria         1985-08-20  4000.75     36     RJ  False
# 2     Pedro         1978-03-10  5000.25     43     MG   True
# 3       Ana         1992-11-28  2500.80     29     RS  False
# 4    Carlos         1980-07-03  3500.60     41     BA  False
# 5     Lúcia         1975-12-18  6000.90     46     PR   True
# 6   Mariana         1987-09-25  3200.45     34     SC  False
# 7  Fernando         1995-02-09  2800.30     27     PE  False
# 8     Lucas         1970-06-14  7000.70     52     AM  False
# 9    Amanda         1983-04-30  4200.55     39     CE   True
# ...

# %% [raw]
# # Fundamentos e Conceitos
#
# - As listas são estruturas de dados fundamentais em muitas linguagens de programação, e cada linguagem tem suas próprias implementações de métodos e funções para manipular listas, em Python temos :
#
# append(elemento): Adiciona um elemento ao final da lista.
# insert(posição, elemento): Insere um elemento em uma posição específica da lista.
# remove(elemento): Remove a primeira ocorrência de um elemento da lista.
# pop([índice]): Remove e retorna em uma posição específica. Se nenhum índice for especificado, o último elemento é removido.
# index(elemento): Retorna o índice da primeira ocorrência de um elemento na lista.
# count(elemento): Retorna o número de ocorrências de um elemento na lista.
# sort(): Ordena os elementos da lista em ordem crescente ou alfabética.
# reverse(): Inverte a ordem dos elementos na lista.
# len(lista): Retorna o número de elementos na lista.
# lista[indice]: Acesso aos elementos da lista pelo seu índice.
# for elemento in lista: Itera sobre todos os elementos da lista.
# in: Verifica se um elemento está presente na lista.
# + (concatenação): Concatena duas listas.
# [:] (slice): Retorna uma parte da lista.
# extend(iterável): Adiciona todos os elementos de um iterável (como outra lista) ao final da lista.
# clear(): Remove todos os elementos da lista.
# copy(): Retorna uma cópia superficial da lista.
# deepcopy(): Retorna uma cópia profunda da lista (quando há objetos aninhados).
# map(função, iterável): Aplica uma função a todos os elementos e retorna um iterador para os resultados.
#
# Esses são apenas alguns exemplos de métodos e funções comuns para manipular listas. A disponibilidade e a sintaxe exata podem variar de acordo com a linguagem de programação utilizada, mas conceitos semelhantes geralmente existem em todas as linguagens. Pessoal, vamos consultar a documentação ?

# %%
print(" Tamanho do list (linhas) : ", len(tabela_dados))
# Out:
#  Tamanho do list (linhas) :  10

# %%
print("Tamanho do list (colunas) : ", len(tabela_dados[0]))
# Out:
# Tamanho do list (colunas) :  6

# %%
# Organizando minha lista pelo elemento 0
# ---------------------------------------

tabela_dados = [
    ["João", "1990-05-15", 3000.50, 31, "SP", False],
    ["Maria", "1985-08-20", 4000.75, 36, "RJ", False],
    ["Pedro", "1978-03-10", 5000.25, 43, "MG", True],
    ["Ana", "1992-11-28", 2500.80, 29, "RS", False],
    ["Carlos", "1980-07-03", 3500.60, 41, "BA", False],
    ["Lúcia", "1975-12-18", 6000.90, 46, "PR", True],
    ["Mariana", "1987-09-25", 3200.45, 34, "SC", False],
    ["Fernando", "1995-02-09", 2800.30, 27, "PE", False],
    ["Lucas", "1970-06-14", 7000.70, 52, "AM", False],
    ["Amanda", "1983-04-30", 4200.55, 39, "CE", True]
]

# Ordenar a lista pelo primeiro elemento de cada sublista
tabela_dados.sort()

# Imprimir a lista ordenada
for linha in tabela_dados:
    print(linha)
    
# Lembre-se : List é mutável, mas quem preenche a lógica dela(e) é o desenvolvedor, então cuidado para não ter
# linhas não uniformes com dados e, por exemplo no lugar do nome ter um valor de conteúdo data. A organização estará
# errada pela disposição dos dados e sua consulta ao elemento retornará algo que não é o que precisa.
# Out:
# ['Amanda', '1983-04-30', 4200.55, 39, 'CE', True]
# ['Ana', '1992-11-28', 2500.8, 29, 'RS', False]
# ['Carlos', '1980-07-03', 3500.6, 41, 'BA', False]
# ['Fernando', '1995-02-09', 2800.3, 27, 'PE', False]
# ['João', '1990-05-15', 3000.5, 31, 'SP', False]
# ['Lucas', '1970-06-14', 7000.7, 52, 'AM', False]
# ['Lúcia', '1975-12-18', 6000.9, 46, 'PR', True]
# ['Maria', '1985-08-20', 4000.75, 36, 'RJ', False]
# ['Mariana', '1987-09-25', 3200.45, 34, 'SC', False]
# ['Pedro', '1978-03-10', 5000.25, 43, 'MG', True]

# %%
# Organizando minha lista pelo elemento 0
# ---------------------------------------

tabela_dados = [
    ["João", "1990-05-15", 3000.50, 31, "SP", False],
    ["Maria", "1985-08-20", 4000.75, 36, "RJ", False],
    ["Pedro", "1978-03-10", 5000.25, 43, "MG", True],
    ["Ana", "1992-11-28", 2500.80, 29, "RS", False],
    ["Carlos", "1980-07-03", 3500.60, 41, "BA", False],
    ["Lúcia", "1975-12-18", 6000.90, 46, "PR", True],
    ["Mariana", "1987-09-25", 3200.45, 34, "SC", False],
    ["Fernando", "1995-02-09", 2800.30, 27, "PE", False],
    ["Lucas", "1970-06-14", 7000.70, 52, "AM", False],
    ["1983-04-30", 4200.55, 39, "CE", True]
]

# Ordenar a lista pelo primeiro elemento de cada sublista
tabela_dados.sort()

# Imprimir a lista ordenada
for linha in tabela_dados:
    print(linha)
    
print("Colunas : ", len(tabela_dados[0]))

# Perceberam que eu alterei uma linha e não significa que todas linhas estão uniformes com relação a quantidade
# acima no exemplo estava demonstrando que eu tenho 6 colunas por linha.
# Out:
# ['1983-04-30', 4200.55, 39, 'CE', True]
# ['Ana', '1992-11-28', 2500.8, 29, 'RS', False]
# ['Carlos', '1980-07-03', 3500.6, 41, 'BA', False]
# ['Fernando', '1995-02-09', 2800.3, 27, 'PE', False]
# ['João', '1990-05-15', 3000.5, 31, 'SP', False]
# ['Lucas', '1970-06-14', 7000.7, 52, 'AM', False]
# ['Lúcia', '1975-12-18', 6000.9, 46, 'PR', True]
# ['Maria', '1985-08-20', 4000.75, 36, 'RJ', False]
# ['Mariana', '1987-09-25', 3200.45, 34, 'SC', False]
# ['Pedro', '1978-03-10', 5000.25, 43, 'MG', True]
# Colunas :  5

# %%
""" 
   Posso ordenar a lista por :
   - função lambda
   - classe
   - função de usuário
   
   Porém em grandes conjuntos de dados eu vou utilizar a ordenação no dataframe 
"""

# com lambda crescente

# Aqui está uma quebra da expressão lambda:

# lambda: é uma palavra-chave do Python que indica que estamos criando uma função anônima.
# x: é o parâmetro da função lambda. Em cada iteração, x representa um item da lista tabela_dados.
# x[1]: é a expressão que especifica como a chave de ordenação será determinada. Neste caso, x[1] significa que estamos
# ordenando com base no segundo elemento de cada sublista.
# reverse=True: é um argumento opcional do método sort() que indica que queremos ordenar em ordem decrescente.
# Seu valor padrão é False, o que significa que a ordenação ocorre em ordem crescente. Quando definido como True, a lista é
# ordenada em ordem decrescente. Em suma, a função lambda é usada para fornecer uma maneira concisa de especificar a chave
# de ordenação sem a necessidade de definir uma função nomeada separada. Ela é muito útil em casos onde a função é simples
# e será usada apenas uma vez.

tabela_dados = [
    ["João", "1990-05-15", 3000.50, 31, "SP", False],
    ["Maria", "1985-08-20", 4000.75, 36, "RJ", False],
    ["Pedro", "1978-03-10", 5000.25, 43, "MG", True],
    ["Ana", "1992-11-28", 2500.80, 29, "RS", False],
    ["Carlos", "1980-07-03", 3500.60, 41, "BA", False],
    ["Lúcia", "1975-12-18", 6000.90, 46, "PR", True],
    ["Mariana", "1987-09-25", 3200.45, 34, "SC", False],
    ["Fernando", "1995-02-09", 2800.30, 27, "PE", False],
    ["Lucas", "1970-06-14", 7000.70, 52, "AM", False],
    ["Amanda", "1983-04-30", 4200.55, 39, "CE", True]
]

# Ordenar a lista pelo primeiro elemento de cada sublista
tabela_dados.sort(key=lambda x: x[0])

# Imprimir a lista ordenada
for linha in tabela_dados:
    print(linha)
# Out:
# ['Amanda', '1983-04-30', 4200.55, 39, 'CE', True]
# ['Ana', '1992-11-28', 2500.8, 29, 'RS', False]
# ['Carlos', '1980-07-03', 3500.6, 41, 'BA', False]
# ['Fernando', '1995-02-09', 2800.3, 27, 'PE', False]
# ['João', '1990-05-15', 3000.5, 31, 'SP', False]
# ['Lucas', '1970-06-14', 7000.7, 52, 'AM', False]
# ['Lúcia', '1975-12-18', 6000.9, 46, 'PR', True]
# ['Maria', '1985-08-20', 4000.75, 36, 'RJ', False]
# ['Mariana', '1987-09-25', 3200.45, 34, 'SC', False]
# ['Pedro', '1978-03-10', 5000.25, 43, 'MG', True]

# %%
# com lambda decrescente

tabela_dados = [
    ["João", "1990-05-15", 3000.50, 31, "SP", False],
    ["Maria", "1985-08-20", 4000.75, 36, "RJ", False],
    ["Pedro", "1978-03-10", 5000.25, 43, "MG", True],
    ["Ana", "1992-11-28", 2500.80, 29, "RS", False],
    ["Carlos", "1980-07-03", 3500.60, 41, "BA", False],
    ["Lúcia", "1975-12-18", 6000.90, 46, "PR", True],
    ["Mariana", "1987-09-25", 3200.45, 34, "SC", False],
    ["Fernando", "1995-02-09", 2800.30, 27, "PE", False],
    ["Lucas", "1970-06-14", 7000.70, 52, "AM", False],
    ["Amanda", "1983-04-30", 4200.55, 39, "CE", True]
]

# Ordenar a lista pelo primeiro elemento de cada sublista
tabela_dados.sort(key=lambda x: x[0], reverse=True)

# Imprimir a lista ordenada
for linha in tabela_dados:
    print(linha)
# Out:
# ['Pedro', '1978-03-10', 5000.25, 43, 'MG', True]
# ['Mariana', '1987-09-25', 3200.45, 34, 'SC', False]
# ['Maria', '1985-08-20', 4000.75, 36, 'RJ', False]
# ['Lúcia', '1975-12-18', 6000.9, 46, 'PR', True]
# ['Lucas', '1970-06-14', 7000.7, 52, 'AM', False]
# ['João', '1990-05-15', 3000.5, 31, 'SP', False]
# ['Fernando', '1995-02-09', 2800.3, 27, 'PE', False]
# ['Carlos', '1980-07-03', 3500.6, 41, 'BA', False]
# ['Ana', '1992-11-28', 2500.8, 29, 'RS', False]
# ['Amanda', '1983-04-30', 4200.55, 39, 'CE', True]

# %%
# Inverter o List

tabela_dados = [
    ["João", "1990-05-15", 3000.50, 31, "SP", False],
    ["Maria", "1985-08-20", 4000.75, 36, "RJ", False],
    ["Pedro", "1978-03-10", 5000.25, 43, "MG", True],
    ["Ana", "1992-11-28", 2500.80, 29, "RS", False],
    ["Carlos", "1980-07-03", 3500.60, 41, "BA", False],
    ["Lúcia", "1975-12-18", 6000.90, 46, "PR", True],
    ["Mariana", "1987-09-25", 3200.45, 34, "SC", False],
    ["Fernando", "1995-02-09", 2800.30, 27, "PE", False],
    ["Lucas", "1970-06-14", 7000.70, 52, "AM", False],
    ["Amanda", "1983-04-30", 4200.55, 39, "CE", True]
]

# Inverter a ordem dos elementos na lista
tabela_dados.reverse()

# Imprimir a lista com a ordem invertida
for linha in tabela_dados:
    print(linha)
# Out:
# ['Amanda', '1983-04-30', 4200.55, 39, 'CE', True]
# ['Lucas', '1970-06-14', 7000.7, 52, 'AM', False]
# ['Fernando', '1995-02-09', 2800.3, 27, 'PE', False]
# ['Mariana', '1987-09-25', 3200.45, 34, 'SC', False]
# ['Lúcia', '1975-12-18', 6000.9, 46, 'PR', True]
# ['Carlos', '1980-07-03', 3500.6, 41, 'BA', False]
# ['Ana', '1992-11-28', 2500.8, 29, 'RS', False]
# ['Pedro', '1978-03-10', 5000.25, 43, 'MG', True]
# ['Maria', '1985-08-20', 4000.75, 36, 'RJ', False]
# ['João', '1990-05-15', 3000.5, 31, 'SP', False]

# %%
# Inverter o List e ordenar

tabela_dados = [
    ["João", "1990-05-15", 3000.50, 31, "SP", False],
    ["Maria", "1985-08-20", 4000.75, 36, "RJ", False],
    ["Pedro", "1978-03-10", 5000.25, 43, "MG", True],
    ["Ana", "1992-11-28", 2500.80, 29, "RS", False],
    ["Carlos", "1980-07-03", 3500.60, 41, "BA", False],
    ["Lúcia", "1975-12-18", 6000.90, 46, "PR", True],
    ["Mariana", "1987-09-25", 3200.45, 34, "SC", False],
    ["Fernando", "1995-02-09", 2800.30, 27, "PE", False],
    ["Lucas", "1970-06-14", 7000.70, 52, "AM", False],
    ["Amanda", "1983-04-30", 4200.55, 39, "CE", True]
]

# Ordenar a lista pelo primeiro elemento de cada sublista em ordem crescente
tabela_dados.sort(key=lambda x: x[0])

# Inverter a ordem da lista
tabela_dados.reverse()

# Imprimir a lista ordenada em ordem reversa
for linha in tabela_dados:
    print(linha)
# Out:
# ['Pedro', '1978-03-10', 5000.25, 43, 'MG', True]
# ['Mariana', '1987-09-25', 3200.45, 34, 'SC', False]
# ['Maria', '1985-08-20', 4000.75, 36, 'RJ', False]
# ['Lúcia', '1975-12-18', 6000.9, 46, 'PR', True]
# ['Lucas', '1970-06-14', 7000.7, 52, 'AM', False]
# ['João', '1990-05-15', 3000.5, 31, 'SP', False]
# ['Fernando', '1995-02-09', 2800.3, 27, 'PE', False]
# ['Carlos', '1980-07-03', 3500.6, 41, 'BA', False]
# ['Ana', '1992-11-28', 2500.8, 29, 'RS', False]
# ['Amanda', '1983-04-30', 4200.55, 39, 'CE', True]
